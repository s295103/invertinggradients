# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from PIL import Image

# %%
# !git clone https://github.com/s295103/invertinggradients.git
# %cd invertinggradients/
# Out:
# fatal: destination path 'invertinggradients' already exists and is not an empty directory.
# /content/invertinggradients

# %% [markdown]
# # Choose variants here:

# %%
arch = 'ResNet20'
num_images = 4
trained_model = False

# %% [markdown]
# ## System setup:

# %%
import inversefed
setup = inversefed.utils.system_startup()
defs = inversefed.training_strategy('conservative')

loss_fn, trainloader, validloader =  inversefed.construct_dataloaders('CIFAR100', defs)

model, _ = inversefed.construct_model(arch, num_classes=100, num_channels=3)
model.to(**setup)
if trained_model:
    epochs = 120
    file = f'{arch}_{epochs}.pth'
    try:
        model.load_state_dict(torch.load(f'models/{file}'))
    except FileNotFoundError:
        inversefed.train(model, loss_fn, trainloader, validloader, defs, setup=setup)
        torch.save(model.state_dict(), f'models/{file}')
model.eval();
# Out:
# Currently evaluating -------------------------------:
# Wednesday, 17. May 2023 06:32PM
# CPUs: 1, GPUs: 1 on d4ccfb51619c.
# GPU : Tesla T4
# Files already downloaded and verified
# Files already downloaded and verified
# Model initialized with random key 2267944158.

# %%
dm = torch.as_tensor(inversefed.consts.cifar10_mean, **setup)[:, None, None]
ds = torch.as_tensor(inversefed.consts.cifar10_std, **setup)[:, None, None]
def plot(tensor):
    tensor = tensor.clone().detach()
    tensor.mul_(ds).add_(dm).clamp_(0, 1)
    if tensor.shape[0] == 1:
        return plt.imshow(tensor[0].permute(1, 2, 0).cpu());
    else:
        fig, axes = plt.subplots(1, tensor.shape[0], figsize=(12, tensor.shape[0]*12))
        for i, im in enumerate(tensor):
            axes[i].imshow(im.permute(1, 2, 0).cpu());

# %% [markdown]
# # Reconstruct

# %% [markdown]
# ### Build the input (ground-truth) gradient

# %%
if num_images == 1:
    ground_truth_image = torch.as_tensor(np.array(Image.open("auto.jpg").resize((32, 32), Image.BICUBIC)) / 255, 
                                         **setup)
    ground_truth = ground_truth_image.permute(2, 0, 1).sub(dm).div(ds).unsqueeze(0).contiguous()
    labels = torch.as_tensor((1,), device=setup['device'])
else:
    ground_truth, labels = [], []
    idx = 25 # choosen randomly ... just whatever you want
    while len(labels) < num_images:
        img, label = validloader.dataset[idx]
        idx += 1
        if label not in labels:
            labels.append(torch.as_tensor((label,), device=setup['device']))
            ground_truth.append(img.to(**setup))
    ground_truth = torch.stack(ground_truth)
    labels = torch.cat(labels)

# %%
plot(ground_truth);
print([validloader.dataset.classes[l] for l in labels]);
# Out:
# ['can', 'keyboard', 'bicycle', 'rose']

# %%
model.zero_grad()
target_loss, _, _ = loss_fn(model(ground_truth), labels)
input_gradient = torch.autograd.grad(target_loss, model.parameters())
input_gradient = [grad.detach() for grad in input_gradient]

# %%
config = dict(signed=True,
              boxed=True,
              cost_fn='sim',
              indices='def',
              weights='equal',
              lr=0.1,
              optim='adam',
              restarts=4,
              max_iterations=24_000,
              total_variation=1e-5,
              init='randn',
              filter='none',
              lr_decay=True,
              scoring_choice='loss')

rec_machine = inversefed.GradientReconstructor(model, (dm, ds), config, num_images=num_images)
output, stats = rec_machine.reconstruct(input_gradient, labels, img_shape=(3, 32, 32))

test_mse = (output.detach() - ground_truth).pow(2).mean()
feat_mse = (model(output.detach())- model(ground_truth)).pow(2).mean()  
test_psnr = inversefed.metrics.psnr(output, ground_truth, factor=1/ds)

plot(output)
plt.title(f"Rec. loss: {stats['opt']:2.4f} | MSE: {test_mse:2.4f} "
          f"| PSNR: {test_psnr:4.2f} | FMSE: {feat_mse:2.4e} |");
# Out:
# It: 0. Rec. loss: 0.0936.
# It: 500. Rec. loss: 0.0070.
# It: 1000. Rec. loss: 0.0058.
# It: 1500. Rec. loss: 0.0058.
# It: 2000. Rec. loss: 0.0058.
# It: 2500. Rec. loss: 0.0046.
# It: 3000. Rec. loss: 0.0060.
# It: 3500. Rec. loss: 0.0051.
# It: 4000. Rec. loss: 0.0047.
# It: 4500. Rec. loss: 0.0048.
# It: 5000. Rec. loss: 0.0060.
# It: 5500. Rec. loss: 0.0045.
# It: 6000. Rec. loss: 0.0047.
# It: 6500. Rec. loss: 0.0052.
# It: 7000. Rec. loss: 0.0057.
# It: 7500. Rec. loss: 0.0068.
# It: 8000. Rec. loss: 0.0057.
# It: 8500. Rec. loss: 0.0056.
# It: 9000. Rec. loss: 0.0061.
# It: 9500. Rec. loss: 0.0054.
# It: 10000. Rec. loss: 0.0050.
# It: 10500. Rec. loss: 0.0040.
# It: 11000. Rec. loss: 0.0035.
# It: 11500. Rec. loss: 0.0037.
# It: 12000. Rec. loss: 0.0048.
# It: 12500. Rec. loss: 0.0044.
# It: 13000. Rec. loss: 0.0050.
# It: 13500. Rec. loss: 0.0047.
# It: 14000. Rec. loss: 0.0041.
# It: 14500. Rec. loss: 0.0048.
# It: 15000. Rec. loss: 0.0046.
# It: 15500. Rec. loss: 0.0044.
# It: 16000. Rec. loss: 0.0039.
# It: 16500. Rec. loss: 0.0038.
# It: 17000. Rec. loss: 0.0042.
# It: 17500. Rec. loss: 0.0043.
# It: 18000. Rec. loss: 0.0039.
# It: 18500. Rec. loss: 0.0045.
# It: 19000. Rec. loss: 0.0038.
# It: 19500. Rec. loss: 0.0038.
# It: 20000. Rec. loss: 0.0036.
# It: 20500. Rec. loss: 0.0039.
# It: 21000. Rec. loss: 0.0036.
# It: 21500. Rec. loss: 0.0036.
# It: 22000. Rec. loss: 0.0041.
# It: 22500. Rec. loss: 0.0040.
# It: 23000. Rec. loss: 0.0039.
# It: 23500. Rec. loss: 0.0040.
# It: 23999. Rec. loss: 0.0037.
# It: 0. Rec. loss: 0.0934.
# It: 500. Rec. loss: 0.0070.
# It: 1000. Rec. loss: 0.0054.
# It: 1500. Rec. loss: 0.0047.
# It: 2000. Rec. loss: 0.0069.
# It: 2500. Rec. loss: 0.0056.
# It: 3000. Rec. loss: 0.0058.
# It: 3500. Rec. loss: 0.0051.
# It: 4000. Rec. loss: 0.0068.
# It: 4500. Rec. loss: 0.0068.
# It: 5000. Rec. loss: 0.0055.
# It: 5500. Rec. loss: 0.0055.
# It: 6000. Rec. loss: 0.0053.
# It: 6500. Rec. loss: 0.0047.
# It: 7000. Rec. loss: 0.0058.
# It: 7500. Rec. loss: 0.0051.
# It: 8000. Rec. loss: 0.0054.
# It: 8500. Rec. loss: 0.0055.
# It: 9000. Rec. loss: 0.0056.
# It: 9500. Rec. loss: 0.0050.
# It: 10000. Rec. loss: 0.0042.
# It: 10500. Rec. loss: 0.0042.
# It: 11000. Rec. loss: 0.0040.
# It: 11500. Rec. loss: 0.0046.
# It: 12000. Rec. loss: 0.0044.
# It: 12500. Rec. loss: 0.0045.
# It: 13000. Rec. loss: 0.0042.
# It: 13500. Rec. loss: 0.0044.
# It: 14000. Rec. loss: 0.0041.
# It: 14500. Rec. loss: 0.0045.
# It: 15000. Rec. loss: 0.0045.
# It: 15500. Rec. loss: 0.0046.
# It: 16000. Rec. loss: 0.0047.
# It: 16500. Rec. loss: 0.0051.
# It: 17000. Rec. loss: 0.0050.
# It: 17500. Rec. loss: 0.0047.
# It: 18000. Rec. loss: 0.0041.
# It: 18500. Rec. loss: 0.0044.
# It: 19000. Rec. loss: 0.0046.
# It: 19500. Rec. loss: 0.0045.
# Recovery interrupted manually in iteration 19680!
# It: 0. Rec. loss: 0.0954.
# It: 500. Rec. loss: 0.0057.
# It: 1000. Rec. loss: 0.0048.
# It: 1500. Rec. loss: 0.0052.
# It: 2000. Rec. loss: 0.0063.
# It: 2500. Rec. loss: 0.0058.
# It: 3000. Rec. loss: 0.0050.
# It: 3500. Rec. loss: 0.0048.
# It: 4000. Rec. loss: 0.0058.
# It: 4500. Rec. loss: 0.0044.
# It: 5000. Rec. loss: 0.0072.
# It: 5500. Rec. loss: 0.0060.
# It: 6000. Rec. loss: 0.0058.
# It: 6500. Rec. loss: 0.0046.
# It: 7000. Rec. loss: 0.0052.
# It: 7500. Rec. loss: 0.0050.
# It: 8000. Rec. loss: 0.0052.
# It: 8500. Rec. loss: 0.0055.
# It: 9000. Rec. loss: 0.0055.
# It: 9500. Rec. loss: 0.0038.
# It: 10000. Rec. loss: 0.0050.
# It: 10500. Rec. loss: 0.0037.
# It: 11000. Rec. loss: 0.0047.
# It: 11500. Rec. loss: 0.0042.
# It: 12000. Rec. loss: 0.0045.
# It: 12500. Rec. loss: 0.0038.
# It: 13000. Rec. loss: 0.0037.
# It: 13500. Rec. loss: 0.0038.
# It: 14000. Rec. loss: 0.0047.
# It: 14500. Rec. loss: 0.0048.
# It: 15000. Rec. loss: 0.0036.
# It: 15500. Rec. loss: 0.0041.
# It: 16000. Rec. loss: 0.0045.
# It: 16500. Rec. loss: 0.0041.
# It: 17000. Rec. loss: 0.0046.
# It: 17500. Rec. loss: 0.0052.
# It: 18000. Rec. loss: 0.0049.
# Recovery interrupted manually in iteration 18344!
# It: 0. Rec. loss: 0.0927.
# Recovery interrupted manually in iteration 23!
# Choosing optimal result ...
# Optimal result score: 0.0037
# Total time: 2435.4783527851105.

# %%
data = inversefed.metrics.activation_errors(model, output, ground_truth)

fig, axes = plt.subplots(2, 3, sharey=False, figsize=(14,8))
axes[0, 0].semilogy(list(data['se'].values())[:-3])
axes[0, 0].set_title('SE')
axes[0, 1].semilogy(list(data['mse'].values())[:-3])
axes[0, 1].set_title('MSE')
axes[0, 2].plot(list(data['sim'].values())[:-3])
axes[0, 2].set_title('Similarity')

convs = [val for key, val in data['mse'].items() if 'conv' in key]
axes[1, 0].semilogy(convs)
axes[1, 0].set_title('MSE - conv layers')
convs = [val for key, val in data['mse'].items() if 'conv1' in key]
axes[1, 1].semilogy(convs)
convs = [val for key, val in data['mse'].items() if 'conv2' in key]
axes[1, 1].semilogy(convs)
axes[1, 1].set_title('MSE - conv1 vs conv2 layers')
bns = [val for key, val in data['mse'].items() if 'bn' in key]
axes[1, 2].plot(bns)
axes[1, 2].set_title('MSE - bn layers')
fig.suptitle('Error between layers');
